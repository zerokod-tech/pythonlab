# %%
#Introduction to Matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot([1,2,3,4]);
plt.show()

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y);

# %%
#1st mmethod
fig = plt.figure() #creates a figure
ax = fig.add_subplot()#add some axes
plt.show()

# %%
#2nd method
fig = plt.figure() #creates a figure
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
#3rd methos ( recomended)
fig, ax = plt.subplots()
ax.plot(x,[50,100,200,250]); #add some data

# %%
#Matplot example workflow

# 0 import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. prepare data
x = [1,2,3,4]
y = [11,22,33,44]

#2. Setup plot
fig, ax = plt.subplots(figsize=(10,10))  #(width, heigh)

# 3. Plot data
ax.plot(x,y)

#4. Customize plot
ax.set(title="Simple Plot",
xlabel="z-axis",
ylabel="y-axis")
    
#5. Save & show (you save the whole figure)
fig.savefig("sample-plot.png")

# %%
## Making figures with Numpy arrays

# %%
# 0 import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data and create a line plot
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
# Plot the data and create a scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# Plot the data and create another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
#make a plot from a dictionary
nut_butter_prices = {"Almond butter":10,
                    "Peanut butter":8,
                    "Cashew butter": 12}
fig,ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Dan's Nut Butter Store", ylabel="Price ($)");

# %%
fig,ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %%
### Two options for subplots

# %%
# Subplot option 1
fig, ((ax1,ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize=(10,5))

#plot to each different axis
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
#Subplots option 2
fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(10,5))

#Plot to each different index
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from pandas DataFrames

# %%
# 0 import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#make a dataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2020",periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#make a dataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales

car_sales["Price"] = car_sales["Price"].str[:-3]
car_sales["Price"] = car_sales["Price"].replace({'\$':''}, regex = True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price
# 0  Toyota  White         150043      4   4,000
# 1   Honda    Red          87899      4   5,000
# 2  Toyota   Blue          32549      3   7,000
# 3     BMW  Black          11179      5  22,000
# 4  Nissan  White         213095      4   3,500
# 5  Toyota  Green          99213      4   4,500
# 6   Honda   Blue          45698      4   7,500
# 7   Honda   Blue          54738      4   7,000
# 8  Toyota  White          60000      4   6,250
# 9  Nissan  White          31600      4   9,700

# %%
car_sales["Price"] = car_sales["Price"].replace({'\$':''}, regex = True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Sale Date  \
# 0  Toyota  White         150043      4   4,000 2020-01-01
# 1   Honda    Red          87899      4   5,000 2020-01-02
# 2  Toyota   Blue          32549      3   7,000 2020-01-03
# 3     BMW  Black          11179      5  22,000 2020-01-04
# 4  Nissan  White         213095      4   3,500 2020-01-05
# 5  Toyota  Green          99213      4   4,500 2020-01-06
# 6   Honda   Blue          45698      4   7,500 2020-01-07
# 7   Honda   Blue          54738      4   7,000 2020-01-08
# 8  Toyota  White          60000      4   6,250 2020-01-09
# 9  Nissan  White          31600      4   9,700 2020-01-10
#
#                                          Total Sales
# 0                                             $4,000
# 1                                       $4,000$5,000
# 2                                 $4,000$5,000$7,000
# 3                          $4,000$5,000$7,000$22,000
# 4                    $4,000$5,000$7,000$22,000$3,500
# ...

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2020",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Sale Date  \
# 0  Toyota  White         150043      4   4,000 2020-01-01
# 1   Honda    Red          87899      4   5,000 2020-01-02
# 2  Toyota   Blue          32549      3   7,000 2020-01-03
# 3     BMW  Black          11179      5  22,000 2020-01-04
# 4  Nissan  White         213095      4   3,500 2020-01-05
# 5  Toyota  Green          99213      4   4,500 2020-01-06
# 6   Honda   Blue          45698      4   7,500 2020-01-07
# 7   Honda   Blue          54738      4   7,000 2020-01-08
# 8  Toyota  White          60000      4   6,250 2020-01-09
# 9  Nissan  White          31600      4   9,700 2020-01-10
#
#                                          Total Sales
# 0                                             $4,000
# 1                                       $4,000$5,000
# 2                                 $4,000$5,000$7,000
# 3                          $4,000$5,000$7,000$22,000
# 4                    $4,000$5,000$7,000$22,000$3,500
# ...

# %%
#make a dataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales

car_sales["Price"] = car_sales["Price"].str[:-3]
car_sales["Price"] = car_sales["Price"].replace({'\$':''}, regex = True)
car_sales["Sale Date"] = pd.date_range("1/1/2020",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Sale Date
# 0  Toyota  White         150043      4   4,000 2020-01-01
# 1   Honda    Red          87899      4   5,000 2020-01-02
# 2  Toyota   Blue          32549      3   7,000 2020-01-03
# 3     BMW  Black          11179      5  22,000 2020-01-04
# 4  Nissan  White         213095      4   3,500 2020-01-05
# 5  Toyota  Green          99213      4   4,500 2020-01-06
# 6   Honda   Blue          45698      4   7,500 2020-01-07
# 7   Honda   Blue          54738      4   7,000 2020-01-08
# 8  Toyota  White          60000      4   6,250 2020-01-09
# 9  Nissan  White          31600      4   9,700 2020-01-10

# %%
#make a dataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales

car_sales["Price"] = car_sales["Price"].str[:-3]
car_sales["Price"] = car_sales["Price"].replace({'\$':''}, regex = True)
car_sales["Sale Date"] = pd.date_range("1/1/2020",periods=len(car_sales))

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Sale Date
# 0  Toyota  White         150043      4   4,000 2020-01-01
# 1   Honda    Red          87899      4   5,000 2020-01-02
# 2  Toyota   Blue          32549      3   7,000 2020-01-03
# 3     BMW  Black          11179      5  22,000 2020-01-04
# 4  Nissan  White         213095      4   3,500 2020-01-05
# 5  Toyota  Green          99213      4   4,500 2020-01-06
# 6   Honda   Blue          45698      4   7,500 2020-01-07
# 7   Honda   Blue          54738      4   7,000 2020-01-08
# 8  Toyota  White          60000      4   6,250 2020-01-09
# 9  Nissan  White          31600      4   9,700 2020-01-10

# %%
#make a dataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales

car_sales["Price"] = car_sales["Price"].str[:-3]
car_sales["Price"] = car_sales["Price"].replace({'\$':''}, regex = True)
car_sales["Sale Date"] = pd.date_range("1/1/2020",periods=len(car_sales))
type(car_sales["Price"])
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Sale Date
# 0  Toyota  White         150043      4   4,000 2020-01-01
# 1   Honda    Red          87899      4   5,000 2020-01-02
# 2  Toyota   Blue          32549      3   7,000 2020-01-03
# 3     BMW  Black          11179      5  22,000 2020-01-04
# 4  Nissan  White         213095      4   3,500 2020-01-05
# 5  Toyota  Green          99213      4   4,500 2020-01-06
# 6   Honda   Blue          45698      4   7,500 2020-01-07
# 7   Honda   Blue          54738      4   7,000 2020-01-08
# 8  Toyota  White          60000      4   6,250 2020-01-09
# 9  Nissan  White          31600      4   9,700 2020-01-10

# %%
    ## bar graph

# %%
# 0 import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
x = np.random.rand(10,4)
x
# Out:
# array([[0.2468789 , 0.59090964, 0.58706744, 0.23572083],
#        [0.73159163, 0.05994448, 0.90555202, 0.58481562],
#        [0.340943  , 0.50435216, 0.52218774, 0.80485346],
#        [0.93503298, 0.23357838, 0.91033697, 0.54507807],
#        [0.92601462, 0.40445672, 0.41422496, 0.55484759],
#        [0.1325182 , 0.3257068 , 0.40940099, 0.39214239],
#        [0.72746703, 0.69733703, 0.36235723, 0.71183484],
#        [0.74590313, 0.36860752, 0.65047856, 0.09207057],
#        [0.03882345, 0.67799858, 0.24312747, 0.24225174],
#        [0.60280232, 0.85189522, 0.65892164, 0.94283622]])

# %%
#make a dataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales

car_sales["Price"] = car_sales["Price"].str[:-3]
car_sales["Price"] = car_sales["Price"].replace({'\$':''}, regex = True)
car_sales["Sale Date"] = pd.date_range("1/1/2020",periods=len(car_sales))
type(car_sales["Price"])
car_sales
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot.hist(bins=5);

# %%
car_sales["Odometer (KM)"].plot.hist(figsize=(10, 30),subplots=True);

# %%
over_50000 =  car_sales["Odometer (KM)"] > 50000
over_50000.head()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4     True
# Name: Odometer (KM), dtype: bool

# %%
#make a dataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales

car_sales["Price"] = car_sales["Price"].str[:-3]
car_sales["Price"] = car_sales["Price"].replace({'\$':''}, regex = True)
car_sales["Sale Date"] = pd.date_range("1/1/2020",periods=len(car_sales))

car_sales.plot(kind="scatter",x='Sale Date',
               y='Odometer (KM)',
               c='Sale Date');

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#00 method
fix,ax = plt.subplots(figsize=(10,6))
car_sales.plot(kind="scatter",x='Sale Date',
               y='Odometer (KM)',
               c='Sale Date', 
               ax=ax);

#ax.set_xlim([45,100])

# %%
#00 method
fix,ax = plt.subplots(figsize=(10,6))

c = np.random.randint(1, 5, size =10)
#color  = [f"C{i}" for i in c]

#plot the data
scatter = ax.scatter(x='Sale Date',
               y='Odometer (KM)',
               c=2);
#add legend
ax.legend(*scatter.legend_elements(),title="Target");

# %%
# subplot of price and km
#00 method
fix,ax = plt.subplots(figsize=(10,6))

c = np.random.randint(1, 5)
#color  = [f"C{i}" for i in c]

#plot the data
scatter = ax.scatter(x=car_sales["Odometer (KM)"],
               y=car_sales["Price"]);
#add legend
ax.legend(*scatter.legend_elements(),title="Target");

# %%
fix.savefig("PriceAndDate.png")

# %%
#seabornm

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)
# Out:
# /Users/roberta/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
